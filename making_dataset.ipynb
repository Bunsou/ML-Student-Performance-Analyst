# %% [markdown]
# ## Making Dataset using the given xlsx file.

# %%
import numpy as np
import pandas as pd

# Read the xlsx file
file_path = "./data/KIT_DSE_Batch 12_Consolidated_Grade_DataSet.xlsx"
df = pd.read_excel(file_path)


# print(df.head(5))
df.head()
# Out:
#   Department of Engineering\nMajor in Software Engineering\nBatch 12  \
# 0                                                NaN
# 1                                                 Nº
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#                      Unnamed: 1         Unnamed: 2  \
# 0                    SEMESTER I                NaN
# 1  Academic Reading and Writing  Community Service
# 2                            81                 81
# 3                            82                 65
# 4                            77                 71
#
#                       Unnamed: 3                   Unnamed: 4  \
# 0                            NaN                          NaN
# 1  Data Structures and Algorithm  Database Management Systems
# 2                             66                           69
# 3                             76                           87
# 4                             76                           76
#
#            Unnamed: 5        Unnamed: 6     Unnamed: 7             Unnamed: 8  \
# 0                 NaN               NaN            NaN                    NaN
# 1  Digital Literacy I  History of Ideas  Mathematics I  Programming in Python
# 2                  80                90             72                     65
# 3                  83                91             66                     78
# 4                  88                86             71                     70
#
#                                 Unnamed: 9  ...  \
# 0                                      NaN  ...
# 1  Public Speaking I: TED in the Classroom  ...
# 2                                       94  ...
# 3                                       87  ...
# 4                                       92  ...
#
#                                          Unnamed: 13             Unnamed: 14  \
# 0                                                NaN                     NaN
# 1  Digital Literacy II: Technology Trends, Issues...  Full Stack Development
# 2                                                 60                      65
# 3                                                 78                      72
# 4                                                 86                      63
#
#                                          Unnamed: 15  \
# 0                                                NaN
# 1  Global Business Leadership and International R...
# 2                                                 62
# 3                                                 72
# 4                                                 62
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1  Introduction to Accounting and Financial Manag...
# 2                                                 60
# 3                                                 72
# 4                                                 79
#
#                         Unnamed: 17  \
# 0                               NaN
# 1  Java with Functional Programming
# 2                                63
# 3                                71
# 4                                65
#
#                                         Unnamed: 18  \
# 0                                               NaN
# 1  Mathematics II: Modern Algebra and Number Theory
# 2                                                77
# 3                                                67
# 4                                                63
#
#                                Unnamed: 19        Unnamed: 20  \
# 0                                      NaN                NaN
# 1  Public Speaking II: TED and the Society  Technical Writing
# 2                                       66                 78
# 3                                       93                 84
# 4                                       69                 83
#
#                    Unnamed: 21             Unnamed: 22
# 0                          NaN                     NaN
# 1  The Arts and the Humanities  Comprehensive Japanese
# 2                           72                   81.28
# 3                           90                   76.51
# 4                           87                   68.41
#
# [5 rows x 23 columns]

# %%
import numpy as np
import pandas as pd

#? Read the xlsx file
raw_file = "./data/KIT_DSE_Batch 12_Consolidated_Grade_DataSet.xlsx"
df = pd.read_excel(raw_file)
# print(df.head(10))


#? select all subjects name
subjects = df.iloc[1,1:].values
# print(subjects)

#? select all students data (score)
student_data = df.iloc[2:, 1:].copy()
# print(student_data)

#? add subjects as columns name in student_data
student_data.columns = subjects
# print(student_data)

#! Data that I've colected through survey
subject_map = {
    'Public Speaking I: TED in the Classroom': ('Soft Subject', 'Practical'),
    'Digital Literacy I': ('Soft Subject', 'Practical'),
    'Academic Reading and Writing': ('Soft Subject', 'Practical'),
    'Science, Technology and Society': ('Soft Subject', 'Theory'),
    'History of Ideas': ('Soft Subject', 'Theory'),
    'The KITian': ('Soft Subject', 'Theory'),
    'Community Service': ('Soft Subject', 'Practical'),
    'Programming in Python': ('Core Subject', 'Practical'),
    'Database Management Systems': ('Core Subject', 'Practical'),
    'Data Structures and Algorithm': ('Core Subject', 'Practical'),
    'Mathematics I': ('Core Subject', 'Theory'),
    'Public Speaking II: TED and the Society': ('Soft Subject', 'Practical'),
    'Digital Literacy II: Technology Trends, Issues, and Challenges in the Digital Age': ('Soft Subject', 'Practical'),
    'Technical Writing': ('Soft Subject', 'Practical'),
    'The Arts and the Humanities': ('Soft Subject', 'Theory'),
    'Global Business Leadership and International Relations': ('Soft Subject', 'Theory'),
    'Introduction to Accounting and Financial Management': ('Soft Subject', 'Theory'),
    'Comprehensive Japanese': ('Soft Subject', 'Practical'),
    'Computer Networks': ('Core Subject', 'Theory'),
    'Full Stack Development': ('Core Subject', 'Practical'),
    'Java with Functional Programming': ('Core Subject', 'Practical'),
    'Mathematics II: Modern Algebra and Number Theory': ('Core Subject', 'Practical')
}

#? rearrange subjects
rearrange_subject = []
for subject in subject_map.keys():
	rearrange_subject.append(subject)

student_data_rearrange = student_data[rearrange_subject]
# print(student_data_rearrange)


#? convert to sample based on each subject and each student
student_dataset = student_data_rearrange.melt(var_name="Subject", value_name="Score")
# print(student_dataset)


#? Add semester for each subject
semester_map = {}
for i, subject in enumerate(rearrange_subject):
    semester_map[subject] = "Semester I" if i < 11 else "Semester II"

student_dataset["Semester"] = student_dataset["Subject"].map(semester_map)
# print(student_dataset.loc[406, ["Subject", "Semester"]])


#? Add Type of Subject and Nature of Subject
student_dataset['Type of Subject'] = student_dataset['Subject'].map(lambda x: subject_map[x][0])
student_dataset['Nature of Subject'] = student_dataset['Subject'].map(lambda x: subject_map[x][1])
# print(student_dataset.head(10))
# print(student_dataset.loc[407, ["Subject", "Type of Subject", "Nature of Subject"]])

#? Reorder columns
student_dataset = student_dataset[[
	"Subject", 
	"Semester", 
	"Type of Subject", 
	"Nature of Subject",
	"Score"
]]
# print(student_dataset.head(10))


#? Save to CSV
csv_path = "./data/KIT_Student_Performance.csv"
student_dataset.to_csv(csv_path, index=False)

# %%
#? import dataset
csv_path = "./data/KIT_Student_Performance.csv"
ds = pd.read_csv(csv_path)
print(ds.head(10))

#? Filter data
ds[(student_dataset['Nature of Subject'] == "Theory")]
# Out:
#                                    Subject    Semester Type of Subject  \
# 0  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 1  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 2  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 3  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 4  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 5  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 6  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 7  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 8  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
# 9  Public Speaking I: TED in the Classroom  Semester I    Soft Subject
#
#   Nature of Subject  Score
# 0         Practical   94.0
# 1         Practical   87.0
# 2         Practical   92.0
# 3         Practical   95.0
# 4         Practical   96.0
# 5         Practical   92.0
# 6         Practical   94.0
# 7         Practical   92.0
# 8         Practical   91.0
# 9         Practical   92.0
#                              Subject     Semester Type of Subject  \
# 111  Science, Technology and Society   Semester I    Soft Subject
# 112  Science, Technology and Society   Semester I    Soft Subject
# 113  Science, Technology and Society   Semester I    Soft Subject
# 114  Science, Technology and Society   Semester I    Soft Subject
# 115  Science, Technology and Society   Semester I    Soft Subject
# ..                               ...          ...             ...
# 698                Computer Networks  Semester II    Core Subject
# 699                Computer Networks  Semester II    Core Subject
# 700                Computer Networks  Semester II    Core Subject
# 701                Computer Networks  Semester II    Core Subject
# 702                Computer Networks  Semester II    Core Subject
#
#     Nature of Subject  Score
# 111            Theory   88.0
# 112            Theory   93.0
# 113            Theory   90.0
# 114            Theory   88.0
# 115            Theory   89.0
# ..                ...    ...
# 698            Theory   74.0
# 699            Theory   66.0
# 700            Theory   63.0
# 701            Theory   81.0
# 702            Theory   70.0
#
# [296 rows x 5 columns]

# %%
# todo: 
# - Data Summary
# - Data Visualization
# - Data Preprocessing
